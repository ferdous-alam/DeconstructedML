# %%
import operator
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
from numpy import arange, sin, pi
np.random.seed(0)
x = arange(0.0, 6.0, 0.1)
y=np.sin(x)+np.random.normal(0,0.15,len(x))
#data=pd.DataFrame(np.column_stack([x,y]),columns=['x','y'])
plt.scatter(x,y)
x = x[:,np.newaxis]
y= y[:,np.newaxis]
temp=331
fig = plt.figure(figsize=(10, 10))
for i in range (6):
    polynomial_features = PolynomialFeatures(degree=i)
    x_poly = polynomial_features.fit_transform(x) 
    model = LinearRegression() 
    model.fit(x_poly,y)
    y_poly_pred = model.predict(x_poly)
    plt.subplot(temp+i)
    plt.scatter(x,y,s=1)
    plt.plot(x,y_poly_pred, color='r')
    plt.legend('%d' %(i+1))
plt.savefig('poly_sin_gauss_noise.eps', format='eps', dpi=1000)

# %%
x = arange(0.0, 6.0, 0.25)
y=np.sin(x)+np.random.normal(0,0.20,len(x))
#data=pd.DataFrame(np.column_stack([x,y]),columns=['x','y'])
x = x[:,np.newaxis]
y= y[:,np.newaxis]
polynomial_features = PolynomialFeatures(degree=14)
x_poly = polynomial_features.fit_transform(x) 
model = LinearRegression() 
model.fit(x_poly,y)
y_poly_pred = model.predict(x_poly)
plt.scatter(x,y)
plt.plot(x,y_poly_pred, color='r')
plt.savefig('poly_sin_gauss_noise_overfitting.eps', format='eps', dpi=1000)
